# %%
# %%capture
! pip install seaborn
! pip install missingno

# %%
#Importar Numpy, Panda, Matplotlib and seaborn
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import missingno as msno

# %%
#Leer base y paginas en la base.
#url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00502/online_retail_II.xlsx"
#data2009= pd.read_excel("https://archive.ics.uci.edu/ml/machine-learning-databases/00502/online_retail_II.xlsx", sheet_name = "Year 2009-2010", header = 0)
#data2010= pd.read_excel("https://archive.ics.uci.edu/ml/machine-learning-databases/00502/online_retail_II.xlsx", sheet_name = "Year 2010-2011", header = 0)

data2009= pd.read_excel("C:/Users/David/Downloads/online_retail_II_MX.xlsx", sheet_name = "Year 2009-2010", header = 0)
data2010= pd.read_excel("C:/Users/David/Downloads/online_retail_II_MX.xlsx", sheet_name = "Year 2010-2011", header = 0)

# %%
#Visualizamos la estructura de las hojas
data2009
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID              Country  Zip Code
# ...

# %%
data2010
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 541905  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 541909  581587      POST                              POSTAGE         1
#
#                InvoiceDate  Price  Customer ID              Country  Zip Code
# ...

# %%
#Se observa que las dos hojas comparten el mismo formato y datos. Y se opta por juntarlos para analizarlos correctamente
data_2009_2010=pd.concat([data2009,data2010], axis=0)
data_2009_2010
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 541905  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 541909  581587      POST                              POSTAGE         1
#
#                InvoiceDate  Price  Customer ID              Country  Zip Code
# ...

# %%
#se verifican los campos para saber su atributo
data_2009_2010.dtypes
# Out:
# Invoice                object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# Price                 float64
# Customer ID           float64
# Country                object
# Zip Code                int64
# dtype: object

# %%
#Verificar el valor nulo
missing_data = data_2009_2010.isnull()
missing_data
# Out:
#         Invoice  StockCode  Description  Quantity  InvoiceDate  Price  \
# 0         False      False        False     False        False  False
# 1         False      False        False     False        False  False
# 2         False      False        False     False        False  False
# 3         False      False        False     False        False  False
# 4         False      False        False     False        False  False
# ...         ...        ...          ...       ...          ...    ...
# 541905    False      False        False     False        False  False
# 541906    False      False        False     False        False  False
# 541907    False      False        False     False        False  False
# 541908    False      False        False     False        False  False
# 541909    False      False        False     False        False  False
#
#         Customer ID  Country  Zip Code
# 0             False    False     False
# 1             False    False     False
# ...

# %%
#vemos los valores nulos en proporcion a la columna analizada
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# Invoice
# False    1067371
# Name: Invoice, dtype: int64
#
# StockCode
# False    1067371
# Name: StockCode, dtype: int64
#
# Description
# False    1062989
# True        4382
# Name: Description, dtype: int64
#
# Quantity
# False    1067371
# Name: Quantity, dtype: int64
#
# InvoiceDate
# False    1067371
# Name: InvoiceDate, dtype: int64
#
# Price
# False    1067371
# Name: Price, dtype: int64
#
# Customer ID
# False    824364
# True     243007
# Name: Customer ID, dtype: int64
#
# Country
# False    1067371
# Name: Country, dtype: int64
#
# Zip Code
# False    1067371
# Name: Zip Code, dtype: int64

# %%
#Visualizamos de manera grafica los valores nulos.
msno.bar(data_2009_2010)
# Out:
# <AxesSubplot:>

# %%
#Descartamos las transacciones que no tiene un Cliente(Customer ID), ya que nos enfocaremos en el analisis del
#comportamiento de los clientes y no de las facturas.
data_2009_2010A = data_2009_2010.dropna()
data_2009_2010A
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 541905  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 541909  581587      POST                              POSTAGE         1
#
#                InvoiceDate  Price  Customer ID              Country  Zip Code
# ...

# %%
msno.bar(data_2009_2010A)
# Out:
# <AxesSubplot:>

# %%
#Se hace una categorización de los productos(categoria, subcategoria) es solo para hacer el analisis más complejo.
#Primero usamos las columnas (stockCode y Description) para eliminar los duplicados y formar una lista de los productos y sus categorización

#Productos_Descripcion = data_2009_2010A.filter(items=['StockCode','Description'])
#Productos_Descripcion

# %%
#Nos quedamos con los valores unicos de ambas columnas
#Productos_DescripcionA=Productos_Descripcion.drop_duplicates()
#Productos_DescripcionA
#Productos_DescripcionA.to_csv('Productos_DescripcionA.csv')

# %%
#Ordenar = Productos_DescripcionA.sort_values(['StockCode','Description'])
#Ordenar.head()

# %%
#Ordenar.tail(17)

# %%
data_2009_2010A['StockCode']= data_2009_2010A['StockCode'].replace('[A-Z]',"", regex = True)
data_2009_2010A
#sku =  Productos_DescripcionA['StockCode'].replace('[A-Z]',"", regex = True)
#sku
# Out:
# <ipython-input-17-0689b377ee82>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2009_2010A['StockCode']= data_2009_2010A['StockCode'].replace('[A-Z]',"", regex = True)
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434     79323                   PINK CHERRY LIGHTS        12
# 2       489434     79323                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# ...

# %%
#Productos_DescripcionA.sort_values(['StockCode','Description'])

# %%
#Productos_DescripcionA['StockCode']=Productos_DescripcionA['StockCode'].astype("str")
#Productos_DescripcionA = Productos_DescripcionA.drop_duplicates(subset = 'StockCode')
#Productos_DescripcionA

# %%
Categoria = []          

for n in data_2009_2010A['StockCode']:
    if n in range (10000, 20000,1):
        Categoria.append('Categoria_1')
    elif n in range (20001, 30000,1):
        Categoria.append('Categoria_2')
    elif n in range (30001, 40000,1):
        Categoria.append('Categoria_3')
    elif n in range (40001, 50000,1):
        Categoria.append('Categoria_4')
    elif n in range (50001, 60000,1):
        Categoria.append('Categoria_5')
    elif n in range (60001, 70000,1):
        Categoria.append('Categoria_6')
    elif n in range (70001, 80000,1):
        Categoria.append('Categoria_7')
    elif n in range (80001, 90000,1):
        Categoria.append('Categoria_8')
    else:
        Categoria.append('Categoria_9')


#Categoria = pd.DataFrame(Categoria,data_2009_2010A['StockCode'])
#Categoria.to_csv('Categoria.csv')
#print(Categoria)

# %%
data_2009_2010A['Categoria'] = Categoria
print(data_2009_2010A)
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434     79323                   PINK CHERRY LIGHTS        12
# 2       489434     79323                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 541905  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 541909  581587                                        POSTAGE         1
#
#                InvoiceDate  Price  Customer ID              Country  Zip Code  \
# ...

# %%
data_2009_2010A.groupby(['Categoria','Country'])['Zip Code'].count()
# Out:
# Categoria    Country
# Categoria_1  Aguascalientes           58
#              Baja California         111
#              Baja California Sur      23
#              Campeche                 17
#              Chiapas                  40
#                                     ...
# Categoria_9  Tamaulipas             1833
#              Tlaxcala                518
#              Veracruz               2833
#              Yucatán                1498
#              Zacatecas               509
# Name: Zip Code, Length: 263, dtype: int64

# %%
import itertools
list_country = [x.split(', ') for x in data_2009_2010A.dropna(subset=['Country'])['Country'].tolist()]
list_country = list(itertools.chain(*list_country))

from collections import Counter
data_country_count = pd.DataFrame(Counter(list_country).most_common()[:32], columns=['Country', 'Count'])

plt.figure(figsize=(12,8))
sns.set(style="darkgrid")
ax = sns.barplot(y="Country", x='Count', data=data_country_count, palette="Set2", orient='h')
